# %%
import numpy as np
a = np.random.normal(size = (10,10,2))

# %%
a
# Out:
# array([[[-0.636215  ,  0.21987995],
#         [ 0.90170118, -0.63130752],
#         [ 0.83669879, -1.32490297],
#         [-0.69608962,  0.02696641],
#         [-1.56960508, -1.34799074],
#         [-1.78975198,  1.5097725 ],
#         [ 0.38873118, -1.09747268],
#         [ 0.11456258,  0.06590798],
#         [-0.71493029, -0.59002124],
#         [-0.05692251,  0.69544495]],
#
#        [[-0.27061285,  0.09821279],
#         [-0.87254639,  0.56151777],
#         [-0.36753625, -0.91977389],
#         [ 1.73686459,  0.37200472],
#         [ 0.56180592, -0.67477363],
#         [ 0.28360657,  0.14248118],
#         [-1.34922482, -0.06511116],
#         [-0.94530204, -0.80661751],
#         [-1.5662648 ,  0.00680082],
#         [ 0.42085161, -0.28253405]],
#
#        [[-0.28825165,  0.9751748 ],
#         [-0.65640896,  0.19224603],
#         [ 0.94492235, -0.78233263],
#         [-0.40703783, -1.26511383],
#         [-0.11038492, -1.60742548],
#         [ 0.25338387,  0.06680326],
# ...

# %%
np.linalg.norm(a, ord = 2, axis = -1)
# Out:
# array([[0.67313945, 1.10073348, 1.56698205, 0.69661176, 2.06899472,
#         2.34150062, 1.16428442, 0.13216825, 0.92695759, 0.69777063],
#        [0.28788377, 1.03761236, 0.99048822, 1.77625621, 0.87803494,
#         0.31738552, 1.35079498, 1.24266961, 1.56627956, 0.50689404],
#        [1.0168849 , 0.68398192, 1.22675287, 1.32898187, 1.6112112 ,
#         0.2620421 , 2.72308049, 0.78841102, 0.95464056, 0.42324208],
#        [1.8346695 , 0.58597482, 1.43120249, 0.56794395, 0.9322456 ,
#         0.50589553, 2.18435618, 1.6058057 , 2.79743946, 0.87142493],
#        [1.62749724, 1.51601998, 3.23746331, 0.46832489, 1.56960636,
#         2.45558345, 1.16069205, 0.90768812, 0.75799527, 0.87840546],
#        [1.25982347, 1.33265673, 1.61872728, 0.62952517, 0.53740985,
#         1.17136608, 2.11967368, 2.49211544, 0.5230644 , 1.90374443],
#        [1.36692429, 1.12567589, 1.24011248, 1.49610684, 0.49888225,
#         0.27082779, 1.3190401 , 0.32222249, 0.64781066, 1.17675136],
# ...
